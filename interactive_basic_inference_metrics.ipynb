# %% [markdown]
# Connected to kpenners (Python 3.12.7)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %%
import torch
import time
import numpy as np
from vllm import LLM, SamplingParams
# Out:
# WARNING 02-09 14:04:14 [cuda.py:608] Detected different devices in the system: Tesla V100-PCIE-32GB, Tesla V100S-PCIE-32GB, Tesla V100S-PCIE-32GB, Tesla V100-PCIE-32GB. Please make sure to set `CUDA_DEVICE_ORDER=PCI_BUS_ID` to avoid unexpected behavior.

# %%
# model defintion
model_id = "./Llama-3.2-1B"
llm = LLM(model_id)

# model prompts
prompts = [
    "Hello, my name is",
    "San Francisco is a",
    "The capital of France is",
    "The future of AI is",
]
sampling_params = SamplingParams(temperature=0.4, top_p=0.95, max_tokens=128)
# Out:
# INFO 02-09 14:05:20 [utils.py:253] non-default args: {'disable_log_stats': True, 'model': './Llama-3.2-1B'}
# INFO 02-09 14:05:20 [model.py:631] Resolved architecture: LlamaForCausalLM
# WARNING 02-09 14:05:20 [model.py:1921] Your device 'Tesla V100-PCIE-32GB' (with compute capability 7.0) doesn't support torch.bfloat16. Falling back to torch.float16 for compatibility.
# WARNING 02-09 14:05:20 [model.py:1971] Casting torch.bfloat16 to torch.float16.
# INFO 02-09 14:05:20 [model.py:1745] Using max model len 131072
# INFO 02-09 14:05:23 [scheduler.py:216] Chunked prefill is enabled with max_num_batched_tokens=8192.
# (EngineCore_DP0 pid=2225173) INFO 02-09 14:05:23 [core.py:93] Initializing a V1 LLM engine (v0.11.2) with config: model='./Llama-3.2-1B', speculative_config=None, tokenizer='./Llama-3.2-1B', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=131072, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=./Llama-3.2-1B, enable_prefix_caching=True, enable_chunked_prefill=True, pooler_config=None, compilation_config={'level': None, 'mode': <CompilationMode.VLLM_COMPILE: 3>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['none'], 'splitting_ops': ['vllm::unified_attention', 'vllm::unified_attention_with_output', 'vllm::unified_mla_attention', 'vllm::unified_mla_attention_with_output', 'vllm::mamba_mixer2', 'vllm::mamba_mixer', 'vllm::short_conv', 'vllm::linear_attention', 'vllm::plamo2_mamba_mixer', 'vllm::gdn_attention_core', 'vllm::kda_attention', 'vllm::sparse_attn_indexer'], 'compile_mm_encoder': False, 'use_inductor': None, 'compile_sizes': [], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.FULL_AND_PIECEWISE: (2, 1)>, 'cudagraph_num_of_warmups': 1, 'cudagraph_capture_sizes': [1, 2, 4, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256, 272, 288, 304, 320, 336, 352, 368, 384, 400, 416, 432, 448, 464, 480, 496, 512], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {}, 'max_cudagraph_capture_size': 512, 'local_cache_dir': None}
# (EngineCore_DP0 pid=2225173) ERROR 02-09 14:05:24 [fa_utils.py:64] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# (EngineCore_DP0 pid=2225173) INFO 02-09 14:05:24 [parallel_state.py:1208] world_size=1 rank=0 local_rank=0 distributed_init_method=tcp://131.155.21.221:46571 backend=nccl
# (EngineCore_DP0 pid=2225173) INFO 02-09 14:05:24 [parallel_state.py:1394] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# (EngineCore_DP0 pid=2225173) INFO 02-09 14:05:25 [gpu_model_runner.py:3259] Starting to load model ./Llama-3.2-1B...
# (EngineCore_DP0 pid=2225173) /home/kpenners/.venv/lib/python3.12/site-packages/tvm_ffi/_optional_torch_c_dlpack.py:174: UserWarning: Failed to JIT torch c dlpack extension, EnvTensorAllocator will not be enabled.
# (EngineCore_DP0 pid=2225173) We recommend installing via `pip install torch-c-dlpack-ext`
# (EngineCore_DP0 pid=2225173)   warnings.warn(
# (EngineCore_DP0 pid=2225173) INFO 02-09 14:05:27 [cuda.py:418] Valid backends: ['TRITON_ATTN', 'FLEX_ATTENTION']
# (EngineCore_DP0 pid=2225173) INFO 02-09 14:05:27 [cuda.py:427] Using TRITON_ATTN backend.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# (EngineCore_DP0 pid=2225173) INFO 02-09 14:05:28 [default_loader.py:314] Loading weights took 0.84 seconds
# (EngineCore_DP0 pid=2225173) INFO 02-09 14:05:29 [gpu_model_runner.py:3338] Model loading took 2.3185 GiB memory and 3.099705 seconds
# (EngineCore_DP0 pid=2225173) INFO 02-09 14:05:33 [backends.py:631] Using cache directory: /home/kpenners/.cache/vllm/torch_compile_cache/7259afe49c/rank_0_0/backbone for vLLM's torch.compile
# (EngineCore_DP0 pid=2225173) INFO 02-09 14:05:33 [backends.py:647] Dynamo bytecode transform time: 3.75 s
# (EngineCore_DP0 pid=2225173) INFO 02-09 14:05:34 [backends.py:210] Directly load the compiled graph(s) for dynamic shape from the cache, took 1.070 s
# (EngineCore_DP0 pid=2225173) INFO 02-09 14:05:34 [monitor.py:34] torch.compile takes 4.82 s in total
# (EngineCore_DP0 pid=2225173) INFO 02-09 14:05:36 [gpu_worker.py:359] Available KV cache memory: 25.01 GiB
# (EngineCore_DP0 pid=2225173) INFO 02-09 14:05:36 [kv_cache_utils.py:1229] GPU KV cache size: 819,392 tokens
# (EngineCore_DP0 pid=2225173) INFO 02-09 14:05:36 [kv_cache_utils.py:1234] Maximum concurrency for 131,072 tokens per request: 6.25x
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100%|██████████| 51/51 [00:01<00:00, 35.39it/s]
# Capturing CUDA graphs (decode, FULL): 100%|██████████| 35/35 [00:04<00:00,  8.54it/s]
# (EngineCore_DP0 pid=2225173) INFO 02-09 14:05:42 [gpu_model_runner.py:4244] Graph capturing finished in 6 secs, took 0.29 GiB
# (EngineCore_DP0 pid=2225173) INFO 02-09 14:05:42 [core.py:250] init engine (profile, create kv cache, warmup model) took 13.79 seconds
# INFO 02-09 14:05:43 [llm.py:352] Supported tasks: ['generate']

# %%
# warm up
_ = llm.generate(prompts)
# Out:
# WARNING 02-09 14:06:24 [model.py:1568] Default sampling parameters have been overridden by the model's Hugging Face generation config recommended from the model creator. If this is not intended, please relaunch vLLM instance with `--generation-config vllm`.
# Adding requests:   0%|          | 0/4 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/4 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]

# %%
outputs = llm.generate(prompts, sampling_params)

for output in outputs:
    prompt = output.prompt
    generated_text = output.outputs[0].text
    print(f"prompt: {prompt!r}, generated text: {generated_text!r}")
# Out:
# Adding requests:   0%|          | 0/4 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/4 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# prompt: 'Hello, my name is', generated text: ' Chris and I am a 19 year old student from the UK. I am currently studying for a BSc in Psychology at the University of Nottingham. I am interested in the study of human behaviour and am currently undertaking a research project into the effects of music on mood and behaviour. I am also interested in the application of psychology in the workplace and am currently undertaking an internship at a local company. My interests include music, video games, psychology and the outdoors.'
# prompt: 'San Francisco is a', generated text: ' city with a lot of history. It is the birthplace of the first transcontinental railroad, and the first transcontinental telephone line. It was also the birthplace of the first transcontinental cable car line. The city is also home to the first skyscraper, the Transamerica Pyramid, which was completed in 1972. San Francisco is also home to many famous landmarks, including the Golden Gate Bridge, Alcatraz Island, and the Golden Gate Park. The city is also home to many famous museums, including the de Young Museum, the Exploratorium, and the San Francisco Museum of Modern Art. San Francisco is also'
# prompt: 'The capital of France is', generated text: ' Paris, and it is the most visited city in the world. Paris is a city of art, culture, fashion, and food. It is also a city of history, with many historical sites and monuments. Paris is a city of romance, with many beautiful parks and gardens. It is also a city of music, with many famous artists and musicians. Paris is a city of love, with many beautiful boulevards and streets. It is also a city of luxury, with many luxury hotels and restaurants. Paris is a city of life, with many people living and working in the city. It is also a city of culture, with'
# prompt: 'The future of AI is', generated text: ' now. It’s time to start thinking about how you can leverage it to grow your business. In this article, we’ll explore the benefits of AI and how it can help you achieve your business goals.\nAI is the future of business. It’s already transforming the way we work, and it’s only going to get more important in the years to come. AI can help you automate tasks, improve customer service, and increase productivity. It can also help you make better decisions and save money.\nBut how do you get started with AI? That’s where we come in. In this article, we’ll give you a crash course on how'

# %%
for prompt in prompts:
    start_time = time.perf_counter()
    outputs = llm.generate(prompt, sampling_params)
    end_time = time.perf_counter()

    output = outputs[0].outputs[0]
    text = output.text
    print(f"prompt: {prompt!r}")
    print(f"generated text: {text!r}")
    print(f"elapsed time: {end_time - start_time:.2f} s")
    print(f"GPU memory used: {torch.cuda.memory_allocated()/1e9:.2f} GB")
    print("-" * 40 )
# Out:
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# prompt: 'Hello, my name is'
# generated text: " Eileen and I am a 19 year old student at the University of Michigan. I am currently working on my Bachelor of Arts in Psychology and I am a member of the Women's Center at the University of Michigan. I am also a member of the Michigan Women's Center and the Women's Resource Center. I am also a member of the Women's Center's Leadership Team. I have been involved in the Women's Center since I was a freshman and have been a part of the Women's Center Leadership Team for the past two years. I have been a member of the Women's Center's Leadership Team for the past two years. I"
# elapsed time: 0.70 s
# GPU memory used: 0.00 GB
# ----------------------------------------
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# prompt: 'San Francisco is a'
# generated text: ' city that is constantly evolving. The city is always changing, and it is always growing. San Francisco is a city that is constantly evolving. The city is always changing, and it is always growing. The city is always changing, and it is always growing. The city is always changing, and it is always growing. The city is always changing, and it is always growing. The city is always changing, and it is always growing. The city is always changing, and it is always growing.\nSan Francisco is a city that is constantly evolving. The city is always changing, and it is always growing. The city is always changing,'
# elapsed time: 0.68 s
# GPU memory used: 0.00 GB
# ----------------------------------------
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# prompt: 'The capital of France is'
# generated text: ' Paris. The French capital is the largest city in France and the capital of France. The city is located on the Seine River and is the most populous city in France. The city is home to many famous landmarks, including the Eiffel Tower, the Louvre Museum, and the Arc de Triomphe. The city is also home to many famous museums, including the Musée d’Orsay and the Musée du Louvre. The city is also home to many famous artists, including Claude Monet and Vincent van Gogh. The city is also home to many famous writers, including Victor Hugo and Alexandre Dumas.'
# elapsed time: 0.69 s
# GPU memory used: 0.00 GB
# ----------------------------------------
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# prompt: 'The future of AI is'
# generated text: ' in the cloud\nArtificial Intelligence (AI) is a hot topic in the tech world, and for good reason. AI has the potential to revolutionize the way we work, learn, and interact with the world around us. But what exactly is AI, and how does it work?\nAI is a subset of machine learning that allows computers to learn from data and make predictions without being explicitly programmed. This means that AI can learn from its experiences and improve over time, making it more accurate and efficient. AI can be used in a variety of applications, including natural language processing, image recognition, and predictive analytics.\nAI is powered by algorithms'
# elapsed time: 0.68 s
# GPU memory used: 0.00 GB
# ----------------------------------------

# %%
for prompt in prompts:
    start_time = time.perf_counter()
    outputs = llm.generate(prompt, sampling_params)
    end_time = time.perf_counter()

    output = outputs[0].outputs[0]
    text = output.text

    print(f"prompt: {prompt!r}")
    print(f"generated text: {text!r}")
    print(f"elapsed time: {end_time - start_time:.2f} s")
    print(f"GPU memory used: {torch.cuda.memory_allocated()/1e9:.2f} GB")
    print("-" * 40 )
# Out:
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# prompt: 'Hello, my name is'
# generated text: ' Chris. I am a 30-year-old male from the UK. I have been married for 4 years and have a 2-year-old son. I am a full-time student and work part-time as a fitness instructor. I have been training for 5 years and have competed in a number of bodybuilding competitions. I have a passion for fitness and am always looking to improve myself. I have been training for the past 5 years and have competed in a number of bodybuilding competitions. I have a passion for fitness and am always looking to improve myself. I have been training for the past 5 years and have competed in'
# elapsed time: 0.69 s
# GPU memory used: 0.00 GB
# ----------------------------------------
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# prompt: 'San Francisco is a'
# generated text: ' city of many neighborhoods, and one of the most popular is the Mission District. The Mission District is a great place to visit if you are looking for a unique experience. The Mission District is a great place to visit if you are looking for a unique experience. The Mission District is a great place to visit if you are looking for a unique experience. The Mission District is a great place to visit if you are looking for a unique experience.\nThe Mission District is a great place to visit if you are looking for a unique experience. The Mission District is a great place to visit if you are looking for a unique experience. The Mission District is'
# elapsed time: 0.68 s
# GPU memory used: 0.00 GB
# ----------------------------------------
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# prompt: 'The capital of France is'
# generated text: ' Paris. It is the largest city in France and the capital of France. It is located in the north of the country. It is the capital of the French region of Île-de-France. It is the most populous city in France. It is the most populous city in Europe. It is the most populous city in the world. It is the most visited city in the world. It is the most visited city in Europe. It is the most visited city in the world. It is the most visited city in Europe. It is the most visited city in the world. It is the most visited city in Europe. It is the'
# elapsed time: 0.68 s
# GPU memory used: 0.00 GB
# ----------------------------------------
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# prompt: 'The future of AI is'
# generated text: ' here. And it’s in the hands of the people. The future of AI is here. And it’s in the hands of the people.\nThe future of AI is here. And it’s in the hands of the people.\nThe future of AI is here. And it’s in the hands of the people.\nThe future of AI is here. And it’s in the hands of the people.\nThe future of AI is here. And it’s in the hands of the people.\nThe future of AI is here. And it’s in the hands of the people.\nThe future of AI is here. And it’s in the hands of'
# elapsed time: 0.68 s
# GPU memory used: 0.00 GB
# ----------------------------------------
